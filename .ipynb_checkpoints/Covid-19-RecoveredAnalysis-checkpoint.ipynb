# %%
import pandas as pd


df = pd.read_csv('time_series_covid19_recovered_global.csv')

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 247            NaN         Western Sahara  24.215500 -12.885800        0
# 248            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 249            NaN                  Yemen  15.552727  48.516388        0
# 250            NaN                Comoros -11.645500  43.333300        0
# 251            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/30/20  5/1/20  \
# ...

# %%
df = df.dropna()
df
# Out:
#                        Province/State  Country/Region      Lat      Long  \
# 8        Australian Capital Territory       Australia -35.4735  149.0124
# 9                     New South Wales       Australia -33.8688  151.2093
# 10                 Northern Territory       Australia -12.4634  130.8456
# 11                         Queensland       Australia -28.0167  153.4000
# 12                    South Australia       Australia -34.9285  138.6007
# ..                                ...             ...      ...       ...
# 236            British Virgin Islands  United Kingdom  18.4207  -64.6400
# 237          Turks and Caicos Islands  United Kingdom  21.6940  -71.7979
# 242  Bonaire, Sint Eustatius and Saba     Netherlands  12.1784  -68.2385
# 244       Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236
# 245         Saint Pierre and Miquelon          France  46.8852  -56.3159
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/30/20  \
# ...
